# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from datetime import datetime #manipulating date fields

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
path_ = "~/Documents/20220720 - Fivier Dataset.csv" #change this to that dataset file

# %%
data = pd.read_csv(path_)
data.head()
# Out:
#           Code  Operation  Workshop                                 Task  \
# 0  100024851.0       10.0  M730AJUS         REVISAR ESTOPADA DE P-2.11-B
# 1  100024960.0       10.0  M730AJUS                LL.GU. REPARAR P4.2-A
# 2  100024961.0       10.0  M730AJUS  LL.GU. REPAR  P4.5 DIPHY MULTIETAPA
# 3  100024583.0       10.0  M730AJUS       SUAVIZAR VALV. ASP. DEL C701-J
# 4  100024544.0       10.0  M730AJUS  REP. C701-I, VALV. ASP. VA MUY DURA
#
#    End Date Worked Hours Unnamed: 6
# 0  1/3/2020         3.50      #REF!
# 1  1/4/2020         0.00      #REF!
# 2  1/5/2020         0.00      #REF!
# 3  1/7/2020         1.00      #REF!
# 4  1/7/2020         7.00      #REF!

# %% [markdown]
# DATA CLEANING

# %%
data.describe
# Out:
# <bound method NDFrame.describe of               Code  Operation  Workshop  \
# 0      100024851.0       10.0  M730AJUS
# 1      100024960.0       10.0  M730AJUS
# 2      100024961.0       10.0  M730AJUS
# 3      100024583.0       10.0  M730AJUS
# 4      100024544.0       10.0  M730AJUS
# ...            ...        ...       ...
# 19455  100041964.0       10.0  M730SOLD
# 19456  100041464.0       10.0  M730SOLD
# 19457  100041549.0       10.0  M730SOLD
# 19458  100026852.0       10.0  M730VARI
# 19459          NaN        NaN       NaN
#
#                                            Task   End Date Worked Hours  \
# 0                  REVISAR ESTOPADA DE P-2.11-B   1/3/2020         3.50
# 1                         LL.GU. REPARAR P4.2-A   1/4/2020         0.00
# 2           LL.GU. REPAR  P4.5 DIPHY MULTIETAPA   1/5/2020         0.00
# 3                SUAVIZAR VALV. ASP. DEL C701-J   1/7/2020         1.00
# 4           REP. C701-I, VALV. ASP. VA MUY DURA   1/7/2020         7.00
# ...

# %%
#fill NaN with 0
data = data.fillna(0)
data.describe
# Out:
# <bound method NDFrame.describe of               Code  Operation  Workshop  \
# 0      100024851.0       10.0  M730AJUS
# 1      100024960.0       10.0  M730AJUS
# 2      100024961.0       10.0  M730AJUS
# 3      100024583.0       10.0  M730AJUS
# 4      100024544.0       10.0  M730AJUS
# ...            ...        ...       ...
# 19455  100041964.0       10.0  M730SOLD
# 19456  100041464.0       10.0  M730SOLD
# 19457  100041549.0       10.0  M730SOLD
# 19458  100026852.0       10.0  M730VARI
# 19459          0.0        0.0         0
#
#                                            Task   End Date Worked Hours  \
# 0                  REVISAR ESTOPADA DE P-2.11-B   1/3/2020         3.50
# 1                         LL.GU. REPARAR P4.2-A   1/4/2020         0.00
# 2           LL.GU. REPAR  P4.5 DIPHY MULTIETAPA   1/5/2020         0.00
# 3                SUAVIZAR VALV. ASP. DEL C701-J   1/7/2020         1.00
# 4           REP. C701-I, VALV. ASP. VA MUY DURA   1/7/2020         7.00
# ...

# %%
data = data.iloc[ : , : 6] # remove the empty column
data.head()
# Out:
#           Code  Operation  Workshop                                 Task  \
# 0  100024851.0       10.0  M730AJUS         REVISAR ESTOPADA DE P-2.11-B
# 1  100024960.0       10.0  M730AJUS                LL.GU. REPARAR P4.2-A
# 2  100024961.0       10.0  M730AJUS  LL.GU. REPAR  P4.5 DIPHY MULTIETAPA
# 3  100024583.0       10.0  M730AJUS       SUAVIZAR VALV. ASP. DEL C701-J
# 4  100024544.0       10.0  M730AJUS  REP. C701-I, VALV. ASP. VA MUY DURA
#
#    End Date Worked Hours
# 0  1/3/2020         3.50
# 1  1/4/2020         0.00
# 2  1/5/2020         0.00
# 3  1/7/2020         1.00
# 4  1/7/2020         7.00

# %% [markdown]
# WORKSHOPS

# %%
workshops = []
for i in data['Workshop'].unique(): # getting distinct values in Workshop column
  print(i)
  workshops.append(i)
print(f"There are {data['Workshop'].nunique()} workshops") #getting the workshop numbers
# Out:
# M730AJUS
# M730ARE1
# M730ARE2
# M730CALO
# M730CELE
# M730CELM
# M720ELEC
# M740INST
# M750OCIV
# M730PINT
# M730PLAS
# M730PLNF
# M730SEGU
# M730SOLD
# M730VARI
# 0
# There are 16 workshops

# %%
#workshops
workshop_1 = data.loc[data['Workshop'] == "M730AJUS"]
workshop_2 = data.loc[data['Workshop'] == "M730ARE1"]
workshop_3 = data.loc[data['Workshop'] == "M730ARE2"]
workshop_4 = data.loc[data['Workshop'] == "M730CALO"]
workshop_5 = data.loc[data['Workshop'] == "M730CELE"]
workshop_6 = data.loc[data['Workshop'] == "M730CELM"]
workshop_7 = data.loc[data['Workshop'] == "M720ELEC"]
workshop_8 = data.loc[data['Workshop'] == "M740INST"]
workshop_9 = data.loc[data['Workshop'] == "M750OCIV"]
workshop_10 = data.loc[data['Workshop'] == "M730PINT"]
workshop_11 = data.loc[data['Workshop'] == "M730PLAS"]
workshop_12 = data.loc[data['Workshop'] == "M730PLNF"]
workshop_13 = data.loc[data['Workshop'] == "M730SEGU"]
workshop_14 = data.loc[data['Workshop'] == "M730SOLD"]
workshop_15 = data.loc[data['Workshop'] == "M730VARI"]
workshop_16 = data.loc[data['Workshop'] == "0"]

# %% [markdown]
# DATA VISUALIZATION

# %% [markdown]
# WORKSHOP ONE (M730AJUS)

# %%
from numpy.ma.core import size
def calc():
  in_house = []
  free_lancers = []
  month_data = []
  years = []
  def calc_():
    sum = 0
    for i in print_data['Worked Hours']:
      sum += round(float(i))
    if sum == 0:
      month_data.append(0)
    else:
      month_data.append(sum)
  def year_():
    for year in range(1, 4):
      sum = 0
      if year == 1:
        print_data = Print_datA[Print_datA['End Date'].str.contains("2020")]
        for y in print_data['Worked Hours']:
          sum += float(y)
        years.append(sum)
      if year == 2:
        print_data = Print_datA[Print_datA['End Date'].str.contains("2021")]
        for y in print_data['Worked Hours']:
          sum += float(y)
        years.append(sum)
      if year == 3:
        print_data = Print_datA[Print_datA['End Date'].str.contains("2022")]
        for y in print_data['Worked Hours']:
          sum += float(y)
        years.append(sum)
    num_hours2 = 0 #yearly worked hours
    total_ = 0
    for hours in years:
      num_hours2 += float(hours)/(4080)
      total_ += 1
  
    #in house workers
    for i in range(0, total_):
      inpt = num_hours2/total_
      in_house.append(inpt)
  
    #freelancers
    for hours_ in years:
      result = (float(hours_)/(4080))-in_house[0]
      if result < 0:
        result = 0
      free_lancers.append(result)

    '''Y_lancers = np.array(free_lancers)
    Y_inhouse = np.array(in_house)
    X_plot = np.array(['2020', '2021', '2022'])
    work_ = []
    for i in years:
      work_.append(float(i)/(4080))
    Y_plot = np.array(work_)
    Y_plot = Y_plot.astype(np.float32)

    plt.figure(figsize=(14,7))
    plt.ylabel("Workers")
    plt.xlabel("YEARS")
    tit = f"WORKERS SUMMARY IN YEARS 2020, 2021 AND 2022 IN WORKSHOP: {workshops[workshop]}"
    plt.title(tit, size=20)
    plt.xticks(rotation = 90)
    plt.plot(X_plot, Y_lancers)
    plt.plot(X_plot, Y_inhouse)
    plt.plot(X_plot, Y_plot)
    plt.legend(["Freelancer Workers", "Inhouse Workers", "All worker"])
    plt.show()'''
  year_()
  in_house = []
  free_lancers = []
  month_data = []
  years = []
  for i in range(1,13):

    if i == 1:
      print_data = print_datA[print_datA['End Date'].str.contains("^1/")]
      calc_()  
    if i == 2:
     print_data = print_datA[print_datA['End Date'].str.contains("^2/")]
     calc_()  
    if i == 3:
     print_data = print_datA[print_datA['End Date'].str.contains("^3")]
     calc_()  
    if i == 4:
     print_data = print_datA[print_datA['End Date'].str.contains("^4")]
     calc_()  
    if i == 5:
     print_data = print_datA[print_datA['End Date'].str.contains("^5")]
     calc_()  
    if i == 6:
     print_data = print_datA[print_datA['End Date'].str.contains("^6")]
     calc_()  
    if i == 7:
     print_data = print_datA[print_datA['End Date'].str.contains("^7")]
     calc_()  
    if i == 8:
     print_data = print_datA[print_datA['End Date'].str.contains("^8")]
     calc_()  
    if i == 9:
     print_data = print_datA[print_datA['End Date'].str.contains("^9")]
     calc_()  
    if i == 10:
     print_data = print_datA[print_datA['End Date'].str.contains("^10")]
     calc_()  
    if i == 11:
     print_data = print_datA[print_datA['End Date'].str.contains("^11")]
     calc_()  
    if i == 12:
     print_data = print_datA[print_datA['End Date'].str.contains("^12")]
     calc_()  
  num_hours2 = 0 #monthly worked hours
  total_ = 0
  for hours in month_data:
    num_hours2 += round(float(hours)/160, 1)
    total_ += 1
  
  #in house workers
  for i in range(0, total_):
    inpt = num_hours2/total_
    in_house.append(round(inpt, 1))
  
  #freelancers
  for hours_ in month_data:
    result = (float(hours_)/160)-in_house[0]
    if result < 0:
      result = 0
    free_lancers.append(round(result, 1))

  Y_lancers = np.array(free_lancers)
  Y_inhouse = np.array(in_house)
  X_plot = np.array(['JANUARY', 'FEBRUARY', 'MARCH', 'APRIL', 'MAY', 'JUNE', 'JULY', 'AUGUST', 'SEPTEMBER', 'OCTOBER', 'NOVERMBER', 'DECEMBER'])
  work_ = []
  for i in month_data:
    work_.append(float(i)/160)
  Y_plot = np.array(work_)
  Y_plot = Y_plot.astype(np.float32)
  plt.figure(figsize=(14,7))
  tit =f'WORKERS BY THE YEAR {yea} for workshop {workshops[workshop]}'
  plt.title(tit, size=20)
  plt.ylabel("Workers")
  plt.xlabel("Month")
  plt.xticks(rotation = 90)
  offset = 0 # adjust so it looks nice, but isn't on your line
  for x, y in zip(X_plot, Y_lancers):
    plt.annotate(y, (x,y+offset))
  plt.plot(X_plot, Y_inhouse)
  z = 1
  for x, y in zip(X_plot, Y_inhouse):
    if z == 1:
      plt.annotate(y, (x,y+offset))
    z += 1
  plt.plot(X_plot, Y_plot)
  for x, y in zip(X_plot, Y_plot):
    plt.annotate(y, (x,y+offset))
  plt.plot(X_plot, Y_lancers)
  #plt.plot(X_plot, Y_inhouse)
  #plt.plot(X_plot, Y_plot)
  all_workers = f"All Workers: {(inpt + (num_hours2 - inpt)/12)}"
  freelancers = f"Freelancers: {(num_hours2-(inpt))/12}"
  inhouse = f"In-house workers: {inpt}"
  plt.legend([inhouse, all_workers, freelancers])
  plt.show()

  def predict_2023():
    def calc_():
      sum = 0
      if i == 7 or i == 8 or i == 9 or i == 10 or i == 11 or i ==12:
        for hours in print_data['Worked Hours']:
          sum += round(float(hours))
        month_data.append(sum)
      else:
        for hours in print_data['Worked Hours']:
          sum += round(float(hours)*2/3)
        month_data.append(sum)

    print_datA = Print_datA[Print_datA['End Date'].str.contains("202")]
    in_house = []
    free_lancers = []
    month_data = []
    for i in range(1,13):

      if i == 1:
        print_data = print_datA[print_datA['End Date'].str.contains("^1/")]
        calc_() 
      if i == 2:
        print_data = print_datA[print_datA['End Date'].str.contains("^2/")]
        calc_()  
      if i == 3:
        print_data = print_datA[print_datA['End Date'].str.contains("^3")]
        calc_()  
      if i == 4:
        print_data = print_datA[print_datA['End Date'].str.contains("^4")]
        calc_()  
      if i == 5:
        print_data = print_datA[print_datA['End Date'].str.contains("^5")]
        calc_()  
      if i == 6:
        print_data = print_datA[print_datA['End Date'].str.contains("^6")]
        calc_()  
      if i == 7:
        print_data = print_datA[print_datA['End Date'].str.contains("^7")]
        calc_()  
      if i == 8:
        print_data = print_datA[print_datA['End Date'].str.contains("^8")]
        calc_()  
      if i == 9:
        print_data = print_datA[print_datA['End Date'].str.contains("^9")]
        calc_()  
      if i == 10:
        print_data = print_datA[print_datA['End Date'].str.contains("^10")]
        calc_()  
      if i == 11:
        print_data = print_datA[print_datA['End Date'].str.contains("^11")]
        calc_()  
      if i == 12:
        print_data = print_datA[print_datA['End Date'].str.contains("^12")]
        calc_()  
    num_hours2 = 0 #monthly worked hours
    total_ = 0
    for hours in month_data:
      num_hours2 += round(float(hours)/(160*2), 1)
      total_ += 1
  
    #in house workers
    for i in range(0, total_):
      inpt = num_hours2/total_
      in_house.append(round(inpt,1))
  
    #freelancers
    for hours_ in month_data:
      result = (float(hours_)/(160*2))-in_house[0]
      if result < 0:
        result = 0
      free_lancers.append(round(result, 1))

    Y_lancers = np.array(free_lancers)
    Y_inhouse = np.array(in_house)
    X_plot = np.array(['JANUARY', 'FEBRUARY', 'MARCH', 'APRIL', 'MAY', 'JUNE', 'JULY', 'AUGUST', 'SEPTEMBER', 'OCTOBER', 'NOVERMBER', 'DECEMBER'])
    work_ = []
    for i in month_data:
      work_.append(float(i)/(160*2))
    Y_plot = np.array(work_)
    Y_plot = Y_plot.astype(np.float32)
    plt.figure(figsize=(14,7))
    tit =f'WORKERS PREDICTED BY THE YEAR 2023 for workshop {workshops[workshop]}'
    plt.title(tit, size=20)
    plt.ylabel("Workers")
    plt.xlabel("Month")
    plt.xticks(rotation = 90)
    plt.plot(X_plot, Y_lancers)
    offset = 0 # adjust so it looks nice, but isn't on your line
    for x, y in zip(X_plot, Y_lancers):
      plt.annotate(y, (x,y+offset))
    plt.plot(X_plot, Y_inhouse)
    z = 1
    for x, y in zip(X_plot, Y_inhouse):
      if z == 1:
        plt.annotate(y, (x,y+offset))
      z += 1
    plt.plot(X_plot, Y_plot)
    for x, y in zip(X_plot, Y_plot):
      plt.annotate(y, (x,y+offset))
    all_workers = f"All Workers: {(inpt + (num_hours2 - inpt)/12)}"
    freelancers = f"Freelancers: {(num_hours2 - inpt)/12}"
    inhouse = f"In-house workers: {inpt}"
    plt.legend([inhouse, all_workers, freelancers])
    plt.show()
  
  if yea == 2022:
    predict_2023()

# %%
from inspect import getcomments
workshop = 0
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent
for hours in workshop_1['Worked Hours']:
  num_hours1 += float(hours)


months = []
print_datA = workshop_1[workshop_1['End Date'].str.contains("2020")]
Print_datA = workshop_1[workshop_1['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_1[workshop_1['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_1[workshop_1['End Date'].str.contains("2022")]
yea = 2022
calc()

# %% [markdown]
# WORKSHOP 2

# %%
from inspect import getcomments
workshop = 1
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent

for hours in workshop_2['Worked Hours']:
  num_hours1 += float(hours)

print_datA = workshop_2[workshop_2['End Date'].str.contains("2020")]
Print_datA = workshop_2[workshop_2['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_2[workshop_2['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_2[workshop_2['End Date'].str.contains("2022")]
yea = 2022
calc()

# %% [markdown]
# WORKSHOP 3

# %%
from inspect import getcomments
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent
workshop = 2
for hours in workshop_3['Worked Hours']:
  num_hours1 += float(hours)

print_datA = workshop_3[workshop_3['End Date'].str.contains("2020")]
Print_datA = workshop_3[workshop_3['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_3[workshop_3['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_3[workshop_3['End Date'].str.contains("2022")]
yea = 2022
calc()

# %% [markdown]
# WORKSHOP 4

# %%
from inspect import getcomments
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent
workshop =3
for hours in workshop_4['Worked Hours']:
  num_hours1 += float(hours)

print_datA = workshop_4[workshop_4['End Date'].str.contains("2020")]
Print_datA = workshop_4[workshop_4['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_4[workshop_4['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_4[workshop_4['End Date'].str.contains("2022")]
yea = 2022
calc()

# %% [markdown]
# WORKSHOP 5

# %%
''
# Out:
# ''

# %%
from inspect import getcomments
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent
workshop = 4
for hours in workshop_5['Worked Hours']:
  num_hours1 += float(hours)


print_datA = workshop_5[workshop_5['End Date'].str.contains("2020")]
Print_datA = workshop_5[workshop_5['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_5[workshop_5['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_5[workshop_5['End Date'].str.contains("2022")]
yea = 2022
calc()

# %% [markdown]
# WORKSHOP 6

# %%
from inspect import getcomments
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent
workshop = 5
for hours in workshop_6['Worked Hours']:
  num_hours1 += float(hours)

print_datA = workshop_6[workshop_6['End Date'].str.contains("2020")]
Print_datA = workshop_6[workshop_6['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_6[workshop_6['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_6[workshop_6['End Date'].str.contains("2022")]
yea = 2022
calc()

# %% [markdown]
# WORKSHOP 7

# %%
from inspect import getcomments
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent
workshop = 6
for hours in workshop_7['Worked Hours']:
  num_hours1 += float(hours)

print_datA = workshop_7[workshop_7['End Date'].str.contains("2020")]
Print_datA = workshop_7[workshop_7['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_7[workshop_7['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_7[workshop_7['End Date'].str.contains("2022")]
yea = 2022
calc()

# %% [markdown]
# WORKSHOP 8

# %%
from inspect import getcomments
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent
workshop = 7
for hours in workshop_8['Worked Hours']:
  num_hours1 += float(hours)

print_datA = workshop_8[workshop_8['End Date'].str.contains("2020")]
Print_datA = workshop_8[workshop_8['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_8[workshop_8['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_8[workshop_8['End Date'].str.contains("2022")]
yea = 2022
calc()

# %% [markdown]
# WORKSHOP 9

# %%
from inspect import getcomments
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent

for hours in workshop_9['Worked Hours']:
  num_hours1 += float(hours)

print_datA = workshop_9[workshop_9['End Date'].str.contains("2020")]
Print_datA = workshop_9[workshop_9['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_9[workshop_9['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_9[workshop_9['End Date'].str.contains("2022")]
yea = 2022
calc()

# %% [markdown]
# WORKSHOP 10

# %%
from inspect import getcomments
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent

for hours in workshop_10['Worked Hours']:
  num_hours1 += float(hours)
workshop =9

print_datA = workshop_10[workshop_10['End Date'].str.contains("2020")]
Print_datA = workshop_10[workshop_10['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_10[workshop_10['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_10[workshop_10['End Date'].str.contains("2022")]
yea = 2022
calc()

# %% [markdown]
# WORKSHOP 11

# %%
from inspect import getcomments
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent

for hours in workshop_11['Worked Hours']:
  num_hours1 += float(hours)
workshop = 10

print_datA = workshop_11[workshop_11['End Date'].str.contains("2020")]
Print_datA = workshop_11[workshop_11['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_11[workshop_11['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_11[workshop_11['End Date'].str.contains("2022")]
yea = 2022
calc()

# %% [markdown]
# WORKSHOP 12

# %%
from inspect import getcomments
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent
workshop = 11
for hours in workshop_12['Worked Hours']:
  num_hours1 += float(hours)

print_datA = workshop_12[workshop_12['End Date'].str.contains("2020")]
Print_datA = workshop_12[workshop_12['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_12[workshop_12['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_12[workshop_12['End Date'].str.contains("2022")]
yea = 2022
calc()

# %% [markdown]
# WORKSHOP 13

# %%
from inspect import getcomments
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent
workshop = 12
for hours in workshop_13['Worked Hours']:
  num_hours1 += float(hours)

print_datA = workshop_13[workshop_13['End Date'].str.contains("2020")]
Print_datA = workshop_13[workshop_13['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_13[workshop_13['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_13[workshop_13['End Date'].str.contains("2022")]
yea = 2022
calc()

# %% [markdown]
# WORKSHOP 14

# %%
from inspect import getcomments
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent
workshop = 13
for hours in workshop_14['Worked Hours']:
  num_hours1 += float(hours)


print_datA = workshop_14[workshop_14['End Date'].str.contains("2020")]
Print_datA = workshop_14[workshop_14['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_14[workshop_14['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_14[workshop_14['End Date'].str.contains("2022")]
yea = 2022
calc()

# %% [markdown]
# WORKSHOP 15

# %%
from inspect import getcomments
num_hours1 = 0 #initializes the number of hours in order to calculate the total number of hours spent
workshop = 14
for hours in workshop_15['Worked Hours']:
  num_hours1 += float(hours)

print_datA = workshop_15[workshop_15['End Date'].str.contains("2020")]
Print_datA = workshop_15[workshop_15['End Date'].str.contains("202")]
yea = 2020
calc()
print_datA = workshop_15[workshop_15['End Date'].str.contains("2021")]
yea = 2021
calc()
print_datA = workshop_15[workshop_15['End Date'].str.contains("2022")]
yea = 2022
calc()
